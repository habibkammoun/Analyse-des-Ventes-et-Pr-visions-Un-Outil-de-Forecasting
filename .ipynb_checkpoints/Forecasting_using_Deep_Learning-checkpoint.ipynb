# %% [markdown]
# # **Packages' Import**

# %%
import pandas            as pd                                   # Library for Read/Write IO File (CSV, Excel, TXT, JSON, etc.)
import matplotlib.pyplot as plt                                  # Library for plotting and figures
from tensorflow.keras.models import Sequential                    # Importation of sequantial Model for LSTM
from tensorflow.keras.layers import LSTM,Dense                    # Importation of LSTM Units
from sklearn.metrics        import mean_squared_error            # Mean Squared Error for forecasting performance evaluation
from sklearn.metrics        import mean_absolute_error           # Mean Absolute Error for forecasting performance evaluation
from sklearn.metrics        import mean_absolute_percentage_error# MAPE for evaluation the percentage of error

# %% [markdown]
# # **Step 1 - Business & Data Understanding**

# %% [markdown]
# The goal of this step is to:
# * identify the number of samples;
# * identify the type of forecasting;
# * study the stationarity of your time series.

# %%
df=pd.read_csv("Retail Sales Dataset - MiniProjet.csv")        # Read dataset using read_csv(filepath) function
df.head()                                               # Display the first five rows
# Out:
#          Date  Sales
# 0  2014-01-01      0
# 1  2014-01-02     70
# 2  2014-01-03     59
# 3  2014-01-04     93
# 4  2014-01-05     96

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 937 entries, 0 to 936
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    937 non-null    object
#  1   Sales   937 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 14.8+ KB

# %% [markdown]
# This dataset includes:
# * 937 samples (2.5 years);
# * Daily Sampled - Short Term;

# %%
plt.xlabel("Day")
plt.ylabel("Number of Sales per day")
plt.plot(df["Sales"])
plt.title("Distribution of the Sales over 2.5 years")
# Out:
# Text(0.5, 1.0, 'Distribution of the Sales over 2.5 years')

# %% [markdown]
# # **Step 2 - Data preparation**

# %% [markdown]
# The goal of this step is to:
# * Construct the X and Y where X denotes the matrix features and y is the label vector;
# * Split dataset into training set and testing set: X_train,X_test,y_train,y_test.

# %% [markdown]
# ## **2.2. Data Loading**

# %%
def load_data(data,seq_len):
  X=[]
  y=[]
  for i in range(seq_len,len(data)):
    X.append(data.iloc[i-seq_len:i,1])
    y.append(data.iloc[i,1])
  return X,y
X,y=load_data(df,80)
print(len(X))
print(len(y))
# Out:
# 857
# 857

# %% [markdown]
# ## **2.2. Data Split**

# %% [markdown]
# We split the dataset into 80% for train and 20% for test

# %%
train_size=len(y)*0.8
print(train_size)
# Out:
# 685.6

# %%
train_size=685

# %%
X_train=X[:train_size]
y_train=y[:train_size]
X_test=X[train_size:]
y_test=y[train_size:]

# %%
print(len(y_train))
print(len(y_test))
# Out:
# 685
# 172

# %%
import numpy as np
X_train=np.array(X_train)
y_train=np.array(y_train)
y_test=np.array(y_test)
X_test=np.array(X_test)
X_train=X_train.reshape(685,80,1)
X_test=X_test.reshape(172,80,1)

# %% [markdown]
# # **Step 3- Deep Learning**

# %%
model=Sequential()
model.add(LSTM(20,input_shape=(80,1)))
model.add(Dense(100))
model.add(Dense(1))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=2, verbose=2)
# Out:
# Epoch 1/100
# 343/343 - 6s - loss: 6654.4556 - 6s/epoch - 17ms/step
# Epoch 2/100
# 343/343 - 3s - loss: 3552.8157 - 3s/epoch - 8ms/step
# Epoch 3/100
# 343/343 - 3s - loss: 3424.0979 - 3s/epoch - 8ms/step
# Epoch 4/100
# 343/343 - 2s - loss: 3370.8740 - 2s/epoch - 7ms/step
# Epoch 5/100
# 343/343 - 3s - loss: 3375.3953 - 3s/epoch - 7ms/step
# Epoch 6/100
# 343/343 - 3s - loss: 3374.8169 - 3s/epoch - 8ms/step
# Epoch 7/100
# 343/343 - 3s - loss: 3365.6963 - 3s/epoch - 9ms/step
# Epoch 8/100
# 343/343 - 3s - loss: 3352.6123 - 3s/epoch - 9ms/step
# Epoch 9/100
# 343/343 - 3s - loss: 3337.3606 - 3s/epoch - 9ms/step
# Epoch 10/100
# 343/343 - 3s - loss: 3255.1724 - 3s/epoch - 9ms/step
# Epoch 11/100
# 343/343 - 3s - loss: 3308.9275 - 3s/epoch - 9ms/step
# Epoch 12/100
# 343/343 - 3s - loss: 3265.8811 - 3s/epoch - 10ms/step
# Epoch 13/100
# 343/343 - 4s - loss: 3324.6614 - 4s/epoch - 11ms/step
# Epoch 14/100
# 343/343 - 3s - loss: 3330.4102 - 3s/epoch - 9ms/step
# Epoch 15/100
# 343/343 - 3s - loss: 3317.2788 - 3s/epoch - 9ms/step
# Epoch 16/100
# 343/343 - 3s - loss: 3258.1016 - 3s/epoch - 9ms/step
# Epoch 17/100
# 343/343 - 3s - loss: 3339.3909 - 3s/epoch - 10ms/step
# Epoch 18/100
# 343/343 - 3s - loss: 3335.9678 - 3s/epoch - 8ms/step
# Epoch 19/100
# 343/343 - 2s - loss: 3319.3508 - 2s/epoch - 7ms/step
# Epoch 20/100
# 343/343 - 3s - loss: 3323.5037 - 3s/epoch - 7ms/step
# Epoch 21/100
# 343/343 - 2s - loss: 3280.7788 - 2s/epoch - 7ms/step
# Epoch 22/100
# 343/343 - 2s - loss: 3304.7795 - 2s/epoch - 6ms/step
# Epoch 23/100
# 343/343 - 2s - loss: 3294.4851 - 2s/epoch - 7ms/step
# Epoch 24/100
# 343/343 - 3s - loss: 3312.0798 - 3s/epoch - 7ms/step
# Epoch 25/100
# 343/343 - 2s - loss: 3326.3760 - 2s/epoch - 6ms/step
# Epoch 26/100
# 343/343 - 2s - loss: 3270.4978 - 2s/epoch - 6ms/step
# Epoch 27/100
# 343/343 - 2s - loss: 3227.9644 - 2s/epoch - 6ms/step
# Epoch 28/100
# 343/343 - 2s - loss: 3248.3193 - 2s/epoch - 7ms/step
# Epoch 29/100
# 343/343 - 2s - loss: 3214.0647 - 2s/epoch - 7ms/step
# Epoch 30/100
# 343/343 - 2s - loss: 3189.8284 - 2s/epoch - 7ms/step
# Epoch 31/100
# 343/343 - 2s - loss: 3274.7981 - 2s/epoch - 7ms/step
# Epoch 32/100
# 343/343 - 2s - loss: 3245.0581 - 2s/epoch - 7ms/step
# Epoch 33/100
# 343/343 - 3s - loss: 3211.6455 - 3s/epoch - 7ms/step
# Epoch 34/100
# 343/343 - 2s - loss: 3195.2537 - 2s/epoch - 7ms/step
# Epoch 35/100
# 343/343 - 3s - loss: 3221.2847 - 3s/epoch - 7ms/step
# Epoch 36/100
# 343/343 - 2s - loss: 3209.7942 - 2s/epoch - 7ms/step
# Epoch 37/100
# 343/343 - 3s - loss: 3176.4194 - 3s/epoch - 7ms/step
# Epoch 38/100
# 343/343 - 2s - loss: 3170.2412 - 2s/epoch - 7ms/step
# Epoch 39/100
# 343/343 - 2s - loss: 3159.5759 - 2s/epoch - 7ms/step
# Epoch 40/100
# 343/343 - 2s - loss: 3171.5229 - 2s/epoch - 7ms/step
# Epoch 41/100
# 343/343 - 2s - loss: 3143.6262 - 2s/epoch - 7ms/step
# Epoch 42/100
# 343/343 - 2s - loss: 3217.4338 - 2s/epoch - 7ms/step
# Epoch 43/100
# 343/343 - 3s - loss: 3137.0120 - 3s/epoch - 8ms/step
# Epoch 44/100
# 343/343 - 3s - loss: 3132.5083 - 3s/epoch - 9ms/step
# Epoch 45/100
# 343/343 - 3s - loss: 3132.0784 - 3s/epoch - 8ms/step
# Epoch 46/100
# 343/343 - 2s - loss: 3161.4807 - 2s/epoch - 7ms/step
# Epoch 47/100
# 343/343 - 2s - loss: 3162.8643 - 2s/epoch - 7ms/step
# Epoch 48/100
# 343/343 - 2s - loss: 3170.3059 - 2s/epoch - 7ms/step
# Epoch 49/100
# 343/343 - 2s - loss: 3127.4663 - 2s/epoch - 7ms/step
# Epoch 50/100
# 343/343 - 3s - loss: 3130.0515 - 3s/epoch - 8ms/step
# Epoch 51/100
# 343/343 - 2s - loss: 3113.6519 - 2s/epoch - 7ms/step
# Epoch 52/100
# 343/343 - 2s - loss: 3102.4861 - 2s/epoch - 7ms/step
# Epoch 53/100
# 343/343 - 2s - loss: 3125.1440 - 2s/epoch - 7ms/step
# Epoch 54/100
# 343/343 - 2s - loss: 3098.7751 - 2s/epoch - 7ms/step
# Epoch 55/100
# 343/343 - 2s - loss: 3107.6174 - 2s/epoch - 7ms/step
# Epoch 56/100
# 343/343 - 2s - loss: 3050.1753 - 2s/epoch - 7ms/step
# Epoch 57/100
# 343/343 - 3s - loss: 3082.1794 - 3s/epoch - 7ms/step
# Epoch 58/100
# 343/343 - 2s - loss: 3044.8525 - 2s/epoch - 7ms/step
# Epoch 59/100
# 343/343 - 2s - loss: 3028.3176 - 2s/epoch - 7ms/step
# Epoch 60/100
# 343/343 - 2s - loss: 3070.6860 - 2s/epoch - 7ms/step
# Epoch 61/100
# 343/343 - 2s - loss: 3040.4143 - 2s/epoch - 7ms/step
# Epoch 62/100
# 343/343 - 2s - loss: 3079.2346 - 2s/epoch - 7ms/step
# Epoch 63/100
# 343/343 - 2s - loss: 3063.6099 - 2s/epoch - 7ms/step
# Epoch 64/100
# 343/343 - 3s - loss: 3045.2305 - 3s/epoch - 8ms/step
# Epoch 65/100
# 343/343 - 2s - loss: 3044.6594 - 2s/epoch - 7ms/step
# Epoch 66/100
# 343/343 - 2s - loss: 3041.5867 - 2s/epoch - 7ms/step
# Epoch 67/100
# 343/343 - 2s - loss: 3032.0684 - 2s/epoch - 7ms/step
# Epoch 68/100
# 343/343 - 2s - loss: 3035.1812 - 2s/epoch - 7ms/step
# Epoch 69/100
# 343/343 - 2s - loss: 3038.0337 - 2s/epoch - 7ms/step
# Epoch 70/100
# 343/343 - 3s - loss: 3071.9563 - 3s/epoch - 8ms/step
# Epoch 71/100
# 343/343 - 3s - loss: 3058.0178 - 3s/epoch - 8ms/step
# Epoch 72/100
# 343/343 - 2s - loss: 3031.8137 - 2s/epoch - 7ms/step
# Epoch 73/100
# 343/343 - 3s - loss: 3043.6880 - 3s/epoch - 8ms/step
# Epoch 74/100
# 343/343 - 2s - loss: 3052.3572 - 2s/epoch - 7ms/step
# Epoch 75/100
# 343/343 - 2s - loss: 3005.8650 - 2s/epoch - 7ms/step
# Epoch 76/100
# 343/343 - 2s - loss: 3017.4724 - 2s/epoch - 7ms/step
# Epoch 77/100
# 343/343 - 2s - loss: 3047.8154 - 2s/epoch - 7ms/step
# Epoch 78/100
# 343/343 - 2s - loss: 2984.9216 - 2s/epoch - 7ms/step
# Epoch 79/100
# 343/343 - 2s - loss: 2972.1292 - 2s/epoch - 6ms/step
# Epoch 80/100
# 343/343 - 2s - loss: 2943.2622 - 2s/epoch - 6ms/step
# Epoch 81/100
# 343/343 - 2s - loss: 2980.0393 - 2s/epoch - 7ms/step
# Epoch 82/100
# 343/343 - 2s - loss: 2957.8406 - 2s/epoch - 6ms/step
# Epoch 83/100
# 343/343 - 2s - loss: 2995.3574 - 2s/epoch - 7ms/step
# Epoch 84/100
# 343/343 - 2s - loss: 2962.6921 - 2s/epoch - 7ms/step
# Epoch 85/100
# 343/343 - 2s - loss: 2959.1274 - 2s/epoch - 6ms/step
# Epoch 86/100
# 343/343 - 2s - loss: 2956.3328 - 2s/epoch - 6ms/step
# Epoch 87/100
# 343/343 - 2s - loss: 2962.4656 - 2s/epoch - 7ms/step
# Epoch 88/100
# 343/343 - 2s - loss: 2926.0229 - 2s/epoch - 7ms/step
# Epoch 89/100
# 343/343 - 2s - loss: 2916.2300 - 2s/epoch - 7ms/step
# Epoch 90/100
# 343/343 - 2s - loss: 2994.5530 - 2s/epoch - 7ms/step
# Epoch 91/100
# 343/343 - 2s - loss: 2917.3525 - 2s/epoch - 7ms/step
# Epoch 92/100
# 343/343 - 2s - loss: 2985.7026 - 2s/epoch - 7ms/step
# Epoch 93/100
# 343/343 - 2s - loss: 2964.5515 - 2s/epoch - 6ms/step
# Epoch 94/100
# 343/343 - 2s - loss: 2975.1716 - 2s/epoch - 7ms/step
# Epoch 95/100
# 343/343 - 2s - loss: 2929.0132 - 2s/epoch - 6ms/step
# Epoch 96/100
# 343/343 - 2s - loss: 2936.2512 - 2s/epoch - 7ms/step
# Epoch 97/100
# 343/343 - 2s - loss: 2940.2388 - 2s/epoch - 7ms/step
# Epoch 98/100
# 343/343 - 3s - loss: 2963.0049 - 3s/epoch - 7ms/step
# Epoch 99/100
# 343/343 - 3s - loss: 2905.1919 - 3s/epoch - 8ms/step
# Epoch 100/100
# 343/343 - 3s - loss: 2965.1306 - 3s/epoch - 8ms/step

# %% [markdown]
# # **Step 4- Performance Evaluation**

# %%
print(" **** Performance of LSTM *****")
y_pred_lstm=model.predict(X_test)
mse=mean_squared_error(y_test,y_pred_lstm)
mae=mean_absolute_error(y_test,y_pred_lstm)
mape=mean_absolute_percentage_error(y_test,y_pred_lstm)
print("MSE= ",mse)
print("MAE= ",mae)
print("MAPEE= ",mape)
# Out:
#  **** Performance of LSTM *****
# 6/6 [==============================] - 1s 6ms/step
# MSE=  5336.5836214254905
# MAE=  50.601967512175094
# MAPEE=  4851100599451649.0

# %%
plt.xlabel("Month")
plt.ylabel("Number of Passenger")
plt.plot(y_test,color='red',label='Real')
plt.plot(y_pred_lstm,color='blue',label='LSTM Regression')
plt.title("ML Experimental Study for Airline Passengers Forecasting")
plt.legend()
